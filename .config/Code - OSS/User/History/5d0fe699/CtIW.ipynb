# %% [markdown]
# ## Formulario Matemática Aplicada - MAT2121

# %% [markdown]
# ### Experiencia de Aprendizaje 1

# %% [markdown]
# #### Importar bibliotecas o librerías

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

# %% [markdown]
# #### Manipulación de listas

# %%
lista = [1, 2, 3, 4]
primer_elemento = lista[0] #Muestra el 1
ultimo_elemento = lista[-1] #Muestra el 4 (ultimo elemento de la lista)

# %% [markdown]
# #### Definición de una función

# %%
def suma(a, b):
    return a + b

# %% [markdown]
# #### Llamar a una función

# %%
resultado = suma(3, 4) # el valor de resultado será 7

# %% [markdown]
# #### Graficar una función

# %%
def f(x):
    return # función a graficar

x = np.arange(v_in, v_fin, paso)
plt.plot(x, f(x), label = 'f(x)')
plt.xlim(v_in,v_fin) #Limites del eje x dados por el contexto del problema
plt.ylim(v_in,v_fin) #Limites del eje y dados por el contexto del problema
plt.title('Nombre del gráfico')
plt.ylabel('Nombre eje y')
plt.xlabel('Nombre eje x')
plt.legend()
plt.show()

# %% [markdown]
# #### Encontrar raíces de una función

# %%
def f(x):
    return #'función igualada a cero'

#Valor/es inicial/es de la aproximación
xo = np.linspace(valor inicial, valor final, cantidad de valores del arreglo)
solucion = fsolve(f, xo)

# %% [markdown]
# #### Encontrar forma algebraica de una función lineal

# %%
# (sirve para sacar la funcion a partir de una tabla)

x = np.array([valor_1, valor_2, valor_3, …, valor_n]) # independiente
y = np.array([valor_1, valor_2, valor_3, …, valor_n]) # dependiente

#Si la función es de grado 1
pendiente, intercepto = np.polyfit(x, y, 1)

print(f"f(x)={pendiente:.2f}x+{intercepto:.2f}")

# %% [markdown]
# ### Encontrar valor especifico de variable independiente

# %%
from scipy.optimize import fsolve
import numpy as np

# igualar la funcion a 0
objetivo = 20

def F(n):
    return 2*1.2**n-objetivo
xo = np.linspace(0, 20, 1)
solucion = fsolve(F,xo)
print(f'{solucion}')
# Out:
# [12.62925314]

# %% [markdown]
# #### Llamado de número Euler en funciones

# %% [markdown]
# **Ejemplo**: **$e^{2}$**

# %%
#FORMA 1
#1) Importando la biblioteca numpy:

import numpy as np

np.exp(2)

# %%
#FORMA 2
#2) Importando e desde la biblioteca math:

from math import e
e**(2)

# %% [markdown]
# ### Experiencia de Aprendizaje 2

# %% [markdown]
# #### Importar bibliotecas o librerías

# %%
import numpy as np

# %% [markdown]
# #### Sucesiones

# %% [markdown]
# Término general de sucesión aritmética:
#
# $$a_{n} = a_{1} + (n - 1)\cdot d$$
#
# Término general de sucesión geométrica:
#
# $$a_{n} = a_{1} \cdot r^{n-1}$$

# %%
#Creación de sucesiones con listas
sucesion = []
for i in range(Cantidad de valores a mostrar):
    n = i + 1
    sucesion.append(Término general)
    print(f'El término {n} es {sucesion[i]}')


#Suma de términos de una lista
suma = sum(sucesion)

# %% [markdown]
# #### Sucesión Aritmética

# %%
def A(n):
  return (a1) + (n - 1) * d

sucesion = []

for i in range(rango):
  n = i+1

  sucesion.append(A(n))

# %% [markdown]
# ### Encontrar Diferencia Sucesión Aritmética

# %%
a4 = 1108000
a12 = 1396000

d = (a12-a4)/8

print(f"la diferencia es: {d:.0f}")

# %% [markdown]
# #### Sucesión Geometrica

# %%
def G(n):
  return (a1) * (r **(n-1))

sucesion = []

for i in range(rango):
  n = i+1

  sucesion.append(G(n))

# %% [markdown]
# #### Encontrar la RAZON de una sucesión Geométrica

# %%
def Razon(aN, aM, n , m):
  k = n - m
  c = aN / aM

  razon =  np.power(c, 1.0 / k)
  return razon
print(f"La razon geometrica de la sucesion es {Razon(5, 40, 3, 6)}")

# %% [markdown]
# #### Encontrar el primer termino de una sucesión

# %%
termino = 5 
pos = 3

a1 = termino / r**(pos-1)

print(f"El primer termino de la sucesion es {a1}")

# %% [markdown]
# #### Encontrar posicion termino de una sucesión

# %%
n = 1 # inicio
fin = 100 # Numero a encontrar
termino = # Geometrica: (a1) * (r **(n-1)) | Aritmética: (a1) + (n - 1) * d  
dif = fin - termino
while dif>0:
  n = n + 1
  termino = # Sucesión a encontrar | Geometrica: (a1) * (r **(n-1)) | Aritmética: (a1) + (n - 1) * d  
  dif = fin - termino
if dif == 0:
  print(f"El termino {fin} pertenece y se encuentra en la posicion {n}")
else:
  print(f"El termino {fin} no pertenece a la sucesion.")

# %% [markdown]
# #### Matrices y aplicaciones

# %%
#Definición de matrices en Python
A = np.array([[elemento, elemento],
              [elemento, elemento]])

B = np.array([[elemento, elemento],
              [elemento, elemento]])

#Suma de matrices
S = A + B

#Resta de matrices
D = B - A

#Transpuesta de una matriz
T = B.T

#Multiplicación de matrices
M = np.dot(A, B)

# %% [markdown]
# #### Creación de matrices mediante función sobre los índices

# %%
D = np.fromfunction(lambda i, j: función_sobre_los_índices, (orden_matriz))
E = np.fromfunction(lambda i, j: función_sobre_los_índices, (orden_matriz))
# Matriz transpuesta
D_t = D.T

# %% [markdown]
# #### Inversa de una matriz

# %%
F = np.array([[elemento, elemento],
              [elemento, elemento]])

F_inv = np.linalg.inv(F)

# %% [markdown]
# Sistema de ecuaciones
#
# \begin{split}
# 2x + y & = 7 \\
# 3x - 2y & = 21
# \end{split}

# %%
A= np.array([
    [2,1],
    [3,-2]
])

B = np.array([
    [7],
    [21]
])

A_inv = np.linalg.inv(A)

C = np.dot(A_inv,B)
print(f'La matriz de las incognitas es:\n\n{C}')
